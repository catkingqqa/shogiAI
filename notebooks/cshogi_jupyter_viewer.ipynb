# %% [markdown]
# # cshogi Jupyter Viewer
#
# 這個 Notebook 示範用 `cshogi` 在 Jupyter / IPython 裡直接顯示將棋盤。

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

import cshogi
from src.notebook_viewer import csa_boards, npz_samples, show, show_many

# %% [markdown]
# ## 1. `cshogi.Board` 直接顯示
#
# 在 Jupyter 裡，最後一行放 `board`，它會自動顯示 SVG 棋盤。

# %%
board = cshogi.Board()
board

# %% [markdown]
# ## 2. 顯示 CSA 棋譜某一手
#
# `csa_boards()` 會把每一步變成可顯示的樣本，棋盤上會高亮下一手。

# %%
csa = csa_boards(ROOT / "data" / "game1.csa", encoding="utf-8")
show(csa[0])

# %%
# 顯示第 51 手，索引從 0 開始，所以第 51 手是 csa[50]
show(csa[50])

# %% [markdown]
# ## 3. 顯示 `.npz` 訓練樣本
#
# 這會顯示棋盤、下一手、move label、value target 與來源資訊。

# %%
samples = npz_samples(ROOT / "out" / "game1.npz")
show(samples[0])

# %%
# 一次顯示前 5 筆
show_many(samples, limit=5)
